# %%
import pandas as pd

matches = pd.read_csv("../01_data/matches.csv")
deliveries = pd.read_csv("../01_data/deliveries.csv")

print("Matches Shape:", matches.shape)
print("Deliveries Shape:", deliveries.shape)

print(matches.head())
print(deliveries.head())
# Out:
# Matches Shape: (1212, 19)
# Deliveries Shape: (288226, 34)
#    match_id        date       city                                      venue  \
# 0   1082591  2017-04-05  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 1   1082592  2017-04-06       Pune    Maharashtra Cricket Association Stadium
# 2   1082593  2017-04-07     Rajkot     Saurashtra Cricket Association Stadium
# 3   1082594  2017-04-08     Indore                     Holkar Cricket Stadium
# 4   1082595  2017-04-08  Bengaluru                      M.Chinnaswamy Stadium
#
#                          team1                        team2  \
# 0          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1       Rising Pune Supergiant               Mumbai Indians
# 2                Gujarat Lions        Kolkata Knight Riders
# 3              Kings XI Punjab       Rising Pune Supergiant
# 4  Royal Challengers Bangalore             Delhi Daredevils
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field          Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field       Rising Pune Supergiant
# 2        Kolkata Knight Riders         field        Kolkata Knight Riders
# 3              Kings XI Punjab         field              Kings XI Punjab
# 4  Royal Challengers Bangalore           bat  Royal Challengers Bangalore
#
#         result_type player_of_match season             event_name match_type  \
# 0  ['by', 'winner']    Yuvraj Singh   2017  Indian Premier League        T20
# 1  ['by', 'winner']       SPD Smith   2017  Indian Premier League        T20
# 2  ['winner', 'by']         CA Lynn   2017  Indian Premier League        T20
# 3  ['by', 'winner']      GJ Maxwell   2017  Indian Premier League        T20
# 4  ['winner', 'by']       KM Jadhav   2017  Indian Premier League        T20
#
#   gender  overs  balls_per_over  team1_won  toss_winner_won
# 0   male     20               6          1                0
# 1   male     20               6          1                1
# 2   male     20               6          0                1
# 3   male     20               6          1                1
# 4   male     20               6          1                1
#    match_id        date season                                      venue  \
# 0   1082591  2017-04-05   2017  Rajiv Gandhi International Stadium, Uppal
# 1   1082591  2017-04-05   2017  Rajiv Gandhi International Stadium, Uppal
# 2   1082591  2017-04-05   2017  Rajiv Gandhi International Stadium, Uppal
# 3   1082591  2017-04-05   2017  Rajiv Gandhi International Stadium, Uppal
# 4   1082591  2017-04-05   2017  Rajiv Gandhi International Stadium, Uppal
#
#         city  innings         batting_team                 bowling_team  over  \
# 0  Hyderabad        1  Sunrisers Hyderabad  Royal Challengers Bangalore     0
# 1  Hyderabad        1  Sunrisers Hyderabad  Royal Challengers Bangalore     0
# 2  Hyderabad        1  Sunrisers Hyderabad  Royal Challengers Bangalore     0
# 3  Hyderabad        1  Sunrisers Hyderabad  Royal Challengers Bangalore     0
# 4  Hyderabad        1  Sunrisers Hyderabad  Royal Challengers Bangalore     0
#
#    ball_in_over  ...  wicket_kind         match_winner  \
# 0             1  ...          NaN  Sunrisers Hyderabad
# 1             2  ...          NaN  Sunrisers Hyderabad
# 2             3  ...          NaN  Sunrisers Hyderabad
# 3             4  ...          NaN  Sunrisers Hyderabad
# 4             5  ...          NaN  Sunrisers Hyderabad
#
#                    toss_winner toss_decision                team1  \
# 0  Royal Challengers Bangalore         field  Sunrisers Hyderabad
# 1  Royal Challengers Bangalore         field  Sunrisers Hyderabad
# 2  Royal Challengers Bangalore         field  Sunrisers Hyderabad
# 3  Royal Challengers Bangalore         field  Sunrisers Hyderabad
# 4  Royal Challengers Bangalore         field  Sunrisers Hyderabad
#
#                          team2  is_powerplay  is_middle_overs  is_death_overs  \
# 0  Royal Challengers Bangalore             1                0               0
# 1  Royal Challengers Bangalore             1                0               0
# 2  Royal Challengers Bangalore             1                0               0
# 3  Royal Challengers Bangalore             1                0               0
# 4  Royal Challengers Bangalore             1                0               0
#
#    batting_team_won
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
#
# [5 rows x 34 columns]
# C:\Users\tannu\AppData\Local\Temp\ipykernel_16724\2606766341.py:4: DtypeWarning: Columns (0: season) have mixed types. Specify dtype option on import or set low_memory=False.
#   deliveries = pd.read_csv("../01_data/deliveries.csv")

# %%
print(matches.columns)
print(deliveries.columns)
# Out:
# Index(['match_id', 'date', 'city', 'venue', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'winner', 'result_type', 'player_of_match', 'season',
#        'event_name', 'match_type', 'gender', 'overs', 'balls_per_over',
#        'team1_won', 'toss_winner_won'],
#       dtype='str')
# Index(['match_id', 'date', 'season', 'venue', 'city', 'innings',
#        'batting_team', 'bowling_team', 'over', 'ball_in_over', 'ball_number',
#        'batter', 'bowler', 'non_striker', 'batter_runs', 'extra_runs',
#        'total_runs', 'wides', 'noballs', 'byes', 'legbyes', 'penalty',
#        'is_wicket', 'wicket_player_out', 'wicket_kind', 'match_winner',
#        'toss_winner', 'toss_decision', 'team1', 'team2', 'is_powerplay',
#        'is_middle_overs', 'is_death_overs', 'batting_team_won'],
#       dtype='str')

# %%
print("Missing values in Matches:")
print(matches.isnull().sum())

print("\nMissing values in Deliveries:")
print(deliveries.isnull().sum())
# Out:
# Missing values in Matches:
# match_id            0
# date                0
# city               51
# venue               0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner             25
# result_type         0
# player_of_match     9
# season              0
# event_name          0
# match_type          0
# gender              0
# overs               0
# balls_per_over      0
# team1_won           0
# toss_winner_won     0
# dtype: int64
#
# Missing values in Deliveries:
# match_id                  0
# date                      0
# season                    0
# venue                     0
# city                  12397
# innings                   0
# batting_team              0
# bowling_team              0
# over                      0
# ball_in_over              0
# ball_number               0
# batter                    0
# bowler                    0
# non_striker               0
# batter_runs               0
# extra_runs                0
# total_runs                0
# wides                     0
# noballs                   0
# byes                      0
# legbyes                   0
# penalty                   0
# is_wicket                 0
# wicket_player_out    273886
# wicket_kind          273886
# match_winner           4980
# toss_winner               0
# toss_decision             0
# team1                     0
# team2                     0
# is_powerplay              0
# is_middle_overs           0
# is_death_overs            0
# batting_team_won          0
# dtype: int64

# %%
print("Available Seasons:")
print(sorted(matches["season"].unique()))
# Out:
# Available Seasons:
# ['2007/08', '2009', '2009/10', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020/21', '2021', '2022', '2023', '2024', '2025', '2026']

# %%
print(matches["season"].unique())
# Out:
# <StringArray>
# [   '2017',    '2018',    '2019', '2020/21',    '2021',    '2022',    '2023',
#     '2024',    '2025',    '2026', '2007/08',    '2009', '2009/10',    '2011',
#     '2012',    '2013',    '2014',    '2015',    '2016']
# Length: 19, dtype: str

# %%
import pandas as pd

matches = pd.read_csv("../01_data/matches.csv")

# %%
print(matches.shape)
print(matches["match_id"].nunique())
# Out:
# (1212, 19)
# 1212
